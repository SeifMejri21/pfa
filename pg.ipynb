# %%
from src.utils.helpers import read_json


dataset_path = "E:/datasets/diwan_jersey/v2"
json_file = "diwan_v2_with_legib_numbers.json"


samples = read_json(f"{dataset_path}/{json_file}")

# %%
samples[55]
# Out:
# {'relative_path': '6450f4ff7310f8045f34152e/crops/person/image4.jpg',
#  'class': 17}

# %%
type(samples)
# Out:
# list
